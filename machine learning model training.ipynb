# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark import SparkContext, SQLContext

appName = "Fifa_dataset"
master = "yarn"

# Create Configuration object for Spark.
conf = pyspark.SparkConf()\
    .set("spark.jars", "gs://task4-data/postgresql-42.6.0.jar")\
    .setAppName(appName)\
    .setMaster(master)

# Create Spark Context with the new configurations rather than relying on the default one
sc = SparkContext.getOrCreate(conf=conf)

# You need to create SQL Context to conduct some database operations like what we will see later.
sqlContext = SQLContext(sc)

# If you have SQL context, you create the session from the Spark Context
spark = sqlContext.sparkSession.builder.getOrCreate()

'''spark = SparkSession.builder.master("yarn").appName("task4").getOrCreate()'''

'''spark = SparkSession.builder.appName("task4").master("yarn").config("spark.jars", "gs://task4-data/postgresql-42.6.0.jar").getOrCreate()'''
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/11/16 08:20:30 INFO SparkEnv: Registering MapOutputTracker
# 23/11/16 08:20:30 INFO SparkEnv: Registering BlockManagerMaster
# 23/11/16 08:20:30 INFO SparkEnv: Registering BlockManagerMasterHeartbeat
# 23/11/16 08:20:30 INFO SparkEnv: Registering OutputCommitCoordinator
# /usr/lib/spark/python/pyspark/sql/context.py:112: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(
# 'spark = SparkSession.builder.appName("task4").master("yarn").config("spark.jars", "gs://task4-data/postgresql-42.6.0.jar").getOrCreate()'

# %%
from pyspark.sql.functions import lit

#converting all the data into one dataframe
dfs = []
for year in range(15, 23):
    file_path = f'gs://task4-data/players_{year}.csv'
    df = spark.read \
    .format("csv") \
    .option("header", "true") \
    .load(file_path)
    df = df.withColumn("year", lit(year))
    print(df.count())
    dfs.append(df)
    
df_final = dfs[0]
for df in dfs[1:]:
    df_final = df_final.union(df)

print(df_final.count())
# Out:
# 16155
# 15623
# 17596
# 17954
# 18085
# 18483
# 18944
# 19239
# [Stage 32:================================================>       (25 + 4) / 29]
# 142079

# %%
from pyspark.sql.functions import monotonically_increasing_id
df_final = df_final.withColumn("Serial_no", monotonically_increasing_id())
#df_final.filter(df_final["row_id"] == 13000).show(vertical=True)
df_final.show(1, vertical=True)
df_final.count()
# Out:
# 23/11/16 08:21:08 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 158023
#  player_url                  | https://sofifa.co...
#  short_name                  | L. Messi
#  long_name                   | Lionel Andrés Mes...
#  player_positions            | CF
#  overall                     | 93
#  potential                   | 95
#  value_eur                   | 100500000.0
#  wage_eur                    | 550000.0
#  age                         | 27
#  dob                         | 1987-06-24
#  height_cm                   | 169
#  weight_kg                   | 67
#  club_team_id                | 241.0
#  club_name                   | FC Barcelona
#  league_name                 | Spain Primera Div...
#  league_level                | 1
#  club_position               | CF
#  club_jersey_number          | 10
#  club_loaned_from            | null
#  club_joined                 | 2004-07-01
#  club_contract_valid_until   | 2018
#  nationality_id              | 52
#  nationality_name            | Argentina
#  nation_team_id              | 1369.0
#  nation_position             | CF
#  nation_jersey_number        | 10
#  preferred_foot              | Left
#  weak_foot                   | 3
#  skill_moves                 | 4
#  international_reputation    | 5
#  work_rate                   | Medium/Low
#  body_type                   | Normal (170-)
#  real_face                   | Yes
#  release_clause_eur          | null
#  player_tags                 | #Speedster, #Drib...
#  player_traits               | Finesse Shot, Spe...
#  pace                        | 93
#  shooting                    | 89
#  passing                     | 86
#  dribbling                   | 96
#  defending                   | 27
#  physic                      | 63
#  attacking_crossing          | 84
#  attacking_finishing         | 94
#  attacking_heading_accuracy  | 71
#  attacking_short_passing     | 89
#  attacking_volleys           | 85
#  skill_dribbling             | 96
#  skill_curve                 | 89
#  skill_fk_accuracy           | 90
#  skill_long_passing          | 76
#  skill_ball_control          | 96
#  movement_acceleration       | 96
#  movement_sprint_speed       | 90
#  movement_agility            | 94
#  movement_reactions          | 94
#  movement_balance            | 95
#  power_shot_power            | 80
#  power_jumping               | 73
#  power_stamina               | 77
#  power_strength              | 60
#  power_long_shots            | 88
#  mentality_aggression        | 48
#  mentality_interceptions     | 22
#  mentality_positioning       | 92
#  mentality_vision            | 90
#  mentality_penalties         | 76
#  mentality_composure         | null
#  defending_marking_awareness | 25
#  defending_standing_tackle   | 21
#  defending_sliding_tackle    | 20
#  goalkeeping_diving          | 6
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 14
#  goalkeeping_reflexes        | 8
#  goalkeeping_speed           | null
#  ls                          | 89+3
#  st                          | 89+3
#  rs                          | 89+3
#  lw                          | 92+3
#  lf                          | 90+3
#  cf                          | 90+3
#  rf                          | 90+3
#  rw                          | 92+3
#  lam                         | 92+3
#  cam                         | 92+3
#  ram                         | 92+3
#  lm                          | 90+3
#  lcm                         | 79+3
#  cm                          | 79+3
#  rcm                         | 79+3
#  rm                          | 90+3
#  lwb                         | 62+3
#  ldm                         | 62+3
#  cdm                         | 62+3
#  rdm                         | 62+3
#  rwb                         | 62+3
#  lb                          | 54+3
#  lcb                         | 45+3
#  cb                          | 45+3
#  rcb                         | 45+3
#  rb                          | 54+3
#  gk                          | 15+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 15
#  Serial_no                   | 0
# only showing top 1 row
# 142079

# %%
db_properties={}
#update your db username
db_properties['username']="postgres"
#update your db password
db_properties['password']="SaiSravan@12"
#make sure you got the right port number here
db_properties['url']= "jdbc:postgresql://35.192.213.82:5432/postgres"
#make sure you had the Postgres JAR file in the right location
db_properties['driver']="org.postgresql.Driver"
db_properties['table']= "Fifa_Dataset"
#db_properties['Schemas'] = 'fifa'

df_final.write.format("jdbc")\
.mode("overwrite")\
.option("url", db_properties['url'])\
.option("dbtable", db_properties['table'])\
.option("user", db_properties['username'])\
.option("password", db_properties['password'])\
.option("driver", db_properties['driver'])\
.save()

# %%
df_final = sqlContext.read.format("jdbc")\
    .option("url", db_properties['url'])\
    .option("dbtable", db_properties['table'])\
    .option("user", db_properties['username'])\
    .option("password", db_properties['password'])\
    .option("Driver", db_properties['driver'])\
    .load()

df_final.show(1, vertical=True)
# Out:
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 158023
#  player_url                  | https://sofifa.co...
#  short_name                  | L. Messi
#  long_name                   | Lionel Andrés Mes...
#  player_positions            | RW, CF
#  overall                     | 94
#  potential                   | 95
#  value_eur                   | 111000000.0
#  wage_eur                    | 550000.0
#  age                         | 28
#  dob                         | 1987-06-24
#  height_cm                   | 170
#  weight_kg                   | 72
#  club_team_id                | 241.0
#  club_name                   | FC Barcelona
#  league_name                 | Spain Primera Div...
#  league_level                | 1
#  club_position               | RW
#  club_jersey_number          | 10
#  club_loaned_from            | null
#  club_joined                 | 2004-07-01
#  club_contract_valid_until   | 2018
#  nationality_id              | 52
#  nationality_name            | Argentina
#  nation_team_id              | 1369.0
#  nation_position             | RW
#  nation_jersey_number        | 10
#  preferred_foot              | Left
#  weak_foot                   | 4
#  skill_moves                 | 4
#  international_reputation    | 5
#  work_rate                   | Medium/Low
#  body_type                   | Unique
#  real_face                   | Yes
#  release_clause_eur          | null
#  player_tags                 | #Speedster, #Drib...
#  player_traits               | Finesse Shot, Spe...
#  pace                        | 92
#  shooting                    | 88
#  passing                     | 86
#  dribbling                   | 95
#  defending                   | 24
#  physic                      | 62
#  attacking_crossing          | 80
#  attacking_finishing         | 93
#  attacking_heading_accuracy  | 71
#  attacking_short_passing     | 88
#  attacking_volleys           | 85
#  skill_dribbling             | 96
#  skill_curve                 | 89
#  skill_fk_accuracy           | 90
#  skill_long_passing          | 79
#  skill_ball_control          | 96
#  movement_acceleration       | 95
#  movement_sprint_speed       | 90
#  movement_agility            | 92
#  movement_reactions          | 92
#  movement_balance            | 95
#  power_shot_power            | 80
#  power_jumping               | 68
#  power_stamina               | 76
#  power_strength              | 59
#  power_long_shots            | 88
#  mentality_aggression        | 48
#  mentality_interceptions     | 22
#  mentality_positioning       | 90
#  mentality_vision            | 90
#  mentality_penalties         | 74
#  mentality_composure         | null
#  defending_marking_awareness | 13
#  defending_standing_tackle   | 23
#  defending_sliding_tackle    | 21
#  goalkeeping_diving          | 6
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 14
#  goalkeeping_reflexes        | 8
#  goalkeeping_speed           | null
#  ls                          | 87+3
#  st                          | 87+3
#  rs                          | 87+3
#  lw                          | 91+3
#  lf                          | 91+3
#  cf                          | 91+3
#  rf                          | 91+3
#  rw                          | 91+3
#  lam                         | 91+3
#  cam                         | 91+3
#  ram                         | 91+3
#  lm                          | 90+3
#  lcm                         | 82+3
#  cm                          | 82+3
#  rcm                         | 82+3
#  rm                          | 90+3
#  lwb                         | 62+3
#  ldm                         | 57+3
#  cdm                         | 57+3
#  rdm                         | 57+3
#  rwb                         | 62+3
#  lb                          | 57+3
#  lcb                         | 44+3
#  cb                          | 44+3
#  rcb                         | 44+3
#  rb                          | 57+3
#  gk                          | 19+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 16
#  Serial_no                   | 25769803776
# only showing top 1 row

# %%
df_final.count()
# Out:
# 142079

# %%
df_final.agg({'overall': 'min', 
               'potential': 'min',
            'club_jersey_number':'min',
             'pace': 'min', 
               'shooting': 'min',
            'passing':'min',
             'dribbling': 'min', 
               'potential': 'min',
            'defending':'min',
             'physic': 'min', 
               'attacking_crossing': 'min',
            'attacking_finishing':'min',
             'attacking_heading_accuracy': 'min', 
               'attacking_short_passing': 'min',
            'attacking_volleys':'min',
             'skill_dribbling': 'min', 
               'skill_curve': 'min',
            'skill_fk_accuracy':'min',
             'skill_long_passing': 'min', 
               'skill_ball_control': 'min',
            'movement_acceleration':'min',
             'movement_sprint_speed': 'min', 
               'movement_agility': 'min',
            'movement_reactions':'min',
              
             'movement_balance': 'min', 
               'power_shot_power': 'min',
            'power_jumping':'min',
             'power_stamina': 'min', 
               'power_strength': 'min',
            'power_long_shots':'min',
             'mentality_aggression': 'min', 
               'mentality_interceptions': 'min',
            'mentality_positioning':'min',
             'mentality_vision': 'min', 
               'mentality_penalties': 'min',
            'mentality_composure':'min',
             'defending_marking_awareness': 'min', 
               'defending_standing_tackle': 'min',
            'defending_sliding_tackle':'min',
             'goalkeeping_diving': 'min', 
               'goalkeeping_handling': 'min',
            'goalkeeping_kicking':'min',
             'goalkeeping_positioning': 'min', 
               'goalkeeping_reflexes': 'min',
            'goalkeeping_speed':'min'}).show(vertical=True)
# Out:
# [Stage 44:>                                                         (0 + 1) / 1]
# -RECORD 0-------------------------------
#  min(mentality_interceptions)     | 10
#  min(skill_curve)                 | 10
#  min(mentality_positioning)       | 10
#  min(mentality_composure)         | 11
#  min(attacking_short_passing)     | 10
#  min(shooting)                    | 14
#  min(power_stamina)               | 10
#  min(club_jersey_number)          | 1
#  min(skill_long_passing)          | 10
#  min(power_jumping)               | 13
#  min(power_strength)              | 12
#  min(defending_standing_tackle)   | 10
#  min(mentality_vision)            | 10
#  min(skill_fk_accuracy)           | 10
#  min(skill_dribbling)             | 10
#  min(movement_agility)            | 11
#  min(goalkeeping_kicking)         | 1
#  min(dribbling)                   | 22
#  min(movement_balance)            | 10
#  min(pace)                        | 21
#  min(mentality_aggression)        | 10
#  min(movement_reactions)          | 20
#  min(movement_sprint_speed)       | 11
#  min(passing)                     | 20
#  min(movement_acceleration)       | 11
#  min(goalkeeping_diving)          | 1
#  min(goalkeeping_speed)           | 12
#  min(attacking_heading_accuracy)  | 10
#  min(defending_sliding_tackle)    | 10
#  min(attacking_volleys)           | 10
#  min(attacking_finishing)         | 10
#  min(defending)                   | 14
#  min(attacking_crossing)          | 10
#  min(power_long_shots)            | 10
#  min(goalkeeping_handling)        | 1
#  min(mentality_penalties)         | 10
#  min(defending_marking_awareness) | 1
#  min(overall)                     | 40
#  min(goalkeeping_reflexes)        | 1
#  min(power_shot_power)            | 10
#  min(goalkeeping_positioning)     | 1
#  min(physic)                      | 27
#  min(skill_ball_control)          | 10
#  min(potential)                   | 40

# %% [markdown]
# ## Task2

# %%
#contract ending in 2023
df_2023 = df_final.filter(df_final.year == 22)

# %%
df_2023.show(3,vertical=True)
# Out:
# -RECORD 0-------------------------------------------
#  sofifa_id                   | 235842
#  player_url                  | https://sofifa.co...
#  short_name                  | A. Pinamonti
#  long_name                   | Andrea Pinamonti
#  player_positions            | ST
#  overall                     | 68
#  potential                   | 75
#  value_eur                   | 2500000.0
#  wage_eur                    | 28000.0
#  age                         | 22
#  dob                         | 1999-05-19
#  height_cm                   | 188
#  weight_kg                   | 72
#  club_team_id                | 1746.0
#  club_name                   | Empoli
#  league_name                 | Italian Serie A
#  league_level                | 1
#  club_position               | SUB
#  club_jersey_number          | 99
#  club_loaned_from            | Inter
#  club_joined                 | null
#  club_contract_valid_until   | 2022
#  nationality_id              | 27
#  nationality_name            | Italy
#  nation_team_id              | null
#  nation_position             | null
#  nation_jersey_number        | null
#  preferred_foot              | Right
#  weak_foot                   | 3
#  skill_moves                 | 3
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (185+)
#  real_face                   | No
#  release_clause_eur          | null
#  player_tags                 | null
#  player_traits               | null
#  pace                        | 63
#  shooting                    | 70
#  passing                     | 45
#  dribbling                   | 67
#  defending                   | 22
#  physic                      | 62
#  attacking_crossing          | 40
#  attacking_finishing         | 73
#  attacking_heading_accuracy  | 70
#  attacking_short_passing     | 53
#  attacking_volleys           | 72
#  skill_dribbling             | 64
#  skill_curve                 | 43
#  skill_fk_accuracy           | 47
#  skill_long_passing          | 36
#  skill_ball_control          | 74
#  movement_acceleration       | 64
#  movement_sprint_speed       | 63
#  movement_agility            | 62
#  movement_reactions          | 67
#  movement_balance            | 64
#  power_shot_power            | 68
#  power_jumping               | 64
#  power_stamina               | 60
#  power_strength              | 66
#  power_long_shots            | 67
#  mentality_aggression        | 52
#  mentality_interceptions     | 16
#  mentality_positioning       | 70
#  mentality_vision            | 45
#  mentality_penalties         | 69
#  mentality_composure         | 60
#  defending_marking_awareness | 15
#  defending_standing_tackle   | 19
#  defending_sliding_tackle    | 19
#  goalkeeping_diving          | 14
#  goalkeeping_handling        | 10
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 7
#  goalkeeping_reflexes        | 11
#  goalkeeping_speed           | null
#  ls                          | 68+2
#  st                          | 68+2
#  rs                          | 68+2
#  lw                          | 63
#  lf                          | 65
#  cf                          | 65
#  rf                          | 65
#  rw                          | 63
#  lam                         | 61+2
#  cam                         | 61+2
#  ram                         | 61+2
#  lm                          | 60+2
#  lcm                         | 53+2
#  cm                          | 53+2
#  rcm                         | 53+2
#  rm                          | 60+2
#  lwb                         | 43+2
#  ldm                         | 41+2
#  cdm                         | 41+2
#  rdm                         | 41+2
#  rwb                         | 43+2
#  lb                          | 41+2
#  lcb                         | 39+2
#  cb                          | 39+2
#  rcb                         | 39+2
#  rb                          | 41+2
#  gk                          | 17+2
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | null
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 22
#  Serial_no                   | 223338300326
# -RECORD 1-------------------------------------------
#  sofifa_id                   | 215363
#  player_url                  | https://sofifa.co...
#  short_name                  | L. Montipò
#  long_name                   | Lorenzo Montipò
#  player_positions            | GK
#  overall                     | 74
#  potential                   | 80
#  value_eur                   | 5000000.0
#  wage_eur                    | 11000.0
#  age                         | 25
#  dob                         | 1996-02-20
#  height_cm                   | 191
#  weight_kg                   | 82
#  club_team_id                | 206.0
#  club_name                   | Hellas Verona
#  league_name                 | Italian Serie A
#  league_level                | 1
#  club_position               | GK
#  club_jersey_number          | 96
#  club_loaned_from            | Benevento
#  club_joined                 | null
#  club_contract_valid_until   | 2022
#  nationality_id              | 27
#  nationality_name            | Italy
#  nation_team_id              | null
#  nation_position             | null
#  nation_jersey_number        | null
#  preferred_foot              | Right
#  weak_foot                   | 2
#  skill_moves                 | 1
#  international_reputation    | 1
#  work_rate                   | Medium/Medium
#  body_type                   | Normal (185+)
#  real_face                   | No
#  release_clause_eur          | null
#  player_tags                 | null
#  player_traits               | null
#  pace                        | null
#  shooting                    | null
#  passing                     | null
#  dribbling                   | null
#  defending                   | null
#  physic                      | null
#  attacking_crossing          | 15
#  attacking_finishing         | 20
#  attacking_heading_accuracy  | 17
#  attacking_short_passing     | 17
#  attacking_volleys           | 18
#  skill_dribbling             | 19
#  skill_curve                 | 17
#  skill_fk_accuracy           | 15
#  skill_long_passing          | 16
#  skill_ball_control          | 20
#  movement_acceleration       | 40
#  movement_sprint_speed       | 42
#  movement_agility            | 46
#  movement_reactions          | 71
#  movement_balance            | 49
#  power_shot_power            | 53
#  power_jumping               | 54
#  power_stamina               | 35
#  power_strength              | 55
#  power_long_shots            | 14
#  mentality_aggression        | 24
#  mentality_interceptions     | 18
#  mentality_positioning       | 15
#  mentality_vision            | 40
#  mentality_penalties         | 29
#  mentality_composure         | 50
#  defending_marking_awareness | 10
#  defending_standing_tackle   | 19
#  defending_sliding_tackle    | 11
#  goalkeeping_diving          | 74
#  goalkeeping_handling        | 71
#  goalkeeping_kicking         | 70
#  goalkeeping_positioning     | 72
#  goalkeeping_reflexes        | 76
#  goalkeeping_speed           | 41
#  ls                          | 30+2
#  st                          | 30+2
#  rs                          | 30+2
#  lw                          | 27
#  lf                          | 29
#  cf                          | 29
#  rf                          | 29
#  rw                          | 27
#  lam                         | 27+2
#  cam                         | 27+2
#  ram                         | 27+2
#  lm                          | 27+2
#  lcm                         | 26+2
#  cm                          | 26+2
#  rcm                         | 26+2
#  rm                          | 27+2
#  lwb                         | 25+2
#  ldm                         | 24+2
#  cdm                         | 24+2
#  rdm                         | 24+2
#  rwb                         | 25+2
#  lb                          | 25+2
#  lcb                         | 25+2
#  cb                          | 25+2
#  rcb                         | 25+2
#  rb                          | 25+2
#  gk                          | 73+2
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | null
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 22
#  Serial_no                   | 214748366953
# -RECORD 2-------------------------------------------
#  sofifa_id                   | 158023
#  player_url                  | https://sofifa.co...
#  short_name                  | L. Messi
#  long_name                   | Lionel Andrés Mes...
#  player_positions            | RW, ST, CF
#  overall                     | 93
#  potential                   | 93
#  value_eur                   | 78000000.0
#  wage_eur                    | 320000.0
#  age                         | 34
#  dob                         | 1987-06-24
#  height_cm                   | 170
#  weight_kg                   | 72
#  club_team_id                | 73.0
#  club_name                   | Paris Saint-Germain
#  league_name                 | French Ligue 1
#  league_level                | 1
#  club_position               | RW
#  club_jersey_number          | 30
#  club_loaned_from            | null
#  club_joined                 | 2021-08-10
#  club_contract_valid_until   | 2023
#  nationality_id              | 52
#  nationality_name            | Argentina
#  nation_team_id              | 1369.0
#  nation_position             | RW
#  nation_jersey_number        | 10
#  preferred_foot              | Left
#  weak_foot                   | 4
#  skill_moves                 | 4
#  international_reputation    | 5
#  work_rate                   | Medium/Low
#  body_type                   | Unique
#  real_face                   | Yes
#  release_clause_eur          | 144300000
#  player_tags                 | #Dribbler, #Dista...
#  player_traits               | Finesse Shot, Lon...
#  pace                        | 85
#  shooting                    | 92
#  passing                     | 91
#  dribbling                   | 95
#  defending                   | 34
#  physic                      | 65
#  attacking_crossing          | 85
#  attacking_finishing         | 95
#  attacking_heading_accuracy  | 70
#  attacking_short_passing     | 91
#  attacking_volleys           | 88
#  skill_dribbling             | 96
#  skill_curve                 | 93
#  skill_fk_accuracy           | 94
#  skill_long_passing          | 91
#  skill_ball_control          | 96
#  movement_acceleration       | 91
#  movement_sprint_speed       | 80
#  movement_agility            | 91
#  movement_reactions          | 94
#  movement_balance            | 95
#  power_shot_power            | 86
#  power_jumping               | 68
#  power_stamina               | 72
#  power_strength              | 69
#  power_long_shots            | 94
#  mentality_aggression        | 44
#  mentality_interceptions     | 40
#  mentality_positioning       | 93
#  mentality_vision            | 95
#  mentality_penalties         | 75
#  mentality_composure         | 96
#  defending_marking_awareness | 20
#  defending_standing_tackle   | 35
#  defending_sliding_tackle    | 24
#  goalkeeping_diving          | 6
#  goalkeeping_handling        | 11
#  goalkeeping_kicking         | 15
#  goalkeeping_positioning     | 14
#  goalkeeping_reflexes        | 8
#  goalkeeping_speed           | null
#  ls                          | 89+3
#  st                          | 89+3
#  rs                          | 89+3
#  lw                          | 92
#  lf                          | 93
#  cf                          | 93
#  rf                          | 93
#  rw                          | 92
#  lam                         | 93
#  cam                         | 93
#  ram                         | 93
#  lm                          | 91+2
#  lcm                         | 87+3
#  cm                          | 87+3
#  rcm                         | 87+3
#  rm                          | 91+2
#  lwb                         | 66+3
#  ldm                         | 64+3
#  cdm                         | 64+3
#  rdm                         | 64+3
#  rwb                         | 66+3
#  lb                          | 61+3
#  lcb                         | 50+3
#  cb                          | 50+3
#  rcb                         | 50+3
#  rb                          | 61+3
#  gk                          | 19+3
#  player_face_url             | https://cdn.sofif...
#  club_logo_url               | https://cdn.sofif...
#  club_flag_url               | https://cdn.sofif...
#  nation_logo_url             | https://cdn.sofif...
#  nation_flag_url             | https://cdn.sofif...
#  year                        | 22
#  Serial_no                   | 214748364800
# only showing top 3 rows

# %%
#Task2 Question1
df_2023 = df_2023.filter(df_2023.club_contract_valid_until == 2023)
def no_of_clubs(X):
    club_counts = df_2023.groupBy("club_name").count()
    top_X_clubs = club_counts.orderBy("count", ascending=False)
    #top_X_clubs.select("club_name").show(X)
    top_x_clubs = top_X_clubs.limit(X)
    top_x_clubs.show(X, vertical=True)

#no_of_clubs(25)

X = int(input("Enter the number of Top teams you want to see: "))
no_of_clubs(X)
# Out:
# Enter the number of Top teams you want to see: 4
# -RECORD 0-------------------------
#  club_name | En Avant de Guingamp
#  count     | 19
# -RECORD 1-------------------------
#  club_name | Club Atlético Lanús
#  count     | 17
# -RECORD 2-------------------------
#  club_name | Lechia Gdańsk
#  count     | 17
# -RECORD 3-------------------------
#  club_name | Barnsley
#  count     | 16

# %%
df_final.printSchema()
# Out:
# root
#  |-- sofifa_id: string (nullable = true)
#  |-- player_url: string (nullable = true)
#  |-- short_name: string (nullable = true)
#  |-- long_name: string (nullable = true)
#  |-- player_positions: string (nullable = true)
#  |-- overall: string (nullable = true)
#  |-- potential: string (nullable = true)
#  |-- value_eur: string (nullable = true)
#  |-- wage_eur: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- dob: string (nullable = true)
#  |-- height_cm: string (nullable = true)
#  |-- weight_kg: string (nullable = true)
#  |-- club_team_id: string (nullable = true)
#  |-- club_name: string (nullable = true)
#  |-- league_name: string (nullable = true)
#  |-- league_level: string (nullable = true)
#  |-- club_position: string (nullable = true)
#  |-- club_jersey_number: string (nullable = true)
#  |-- club_loaned_from: string (nullable = true)
#  |-- club_joined: string (nullable = true)
#  |-- club_contract_valid_until: string (nullable = true)
#  |-- nationality_id: string (nullable = true)
#  |-- nationality_name: string (nullable = true)
#  |-- nation_team_id: string (nullable = true)
#  |-- nation_position: string (nullable = true)
#  |-- nation_jersey_number: string (nullable = true)
#  |-- preferred_foot: string (nullable = true)
#  |-- weak_foot: string (nullable = true)
#  |-- skill_moves: string (nullable = true)
#  |-- international_reputation: string (nullable = true)
#  |-- work_rate: string (nullable = true)
#  |-- body_type: string (nullable = true)
#  |-- real_face: string (nullable = true)
#  |-- release_clause_eur: string (nullable = true)
#  |-- player_tags: string (nullable = true)
#  |-- player_traits: string (nullable = true)
#  |-- pace: string (nullable = true)
#  |-- shooting: string (nullable = true)
#  |-- passing: string (nullable = true)
#  |-- dribbling: string (nullable = true)
#  |-- defending: string (nullable = true)
#  |-- physic: string (nullable = true)
#  |-- attacking_crossing: string (nullable = true)
#  |-- attacking_finishing: string (nullable = true)
#  |-- attacking_heading_accuracy: string (nullable = true)
#  |-- attacking_short_passing: string (nullable = true)
#  |-- attacking_volleys: string (nullable = true)
#  |-- skill_dribbling: string (nullable = true)
#  |-- skill_curve: string (nullable = true)
#  |-- skill_fk_accuracy: string (nullable = true)
#  |-- skill_long_passing: string (nullable = true)
#  |-- skill_ball_control: string (nullable = true)
#  |-- movement_acceleration: string (nullable = true)
#  |-- movement_sprint_speed: string (nullable = true)
#  |-- movement_agility: string (nullable = true)
#  |-- movement_reactions: string (nullable = true)
#  |-- movement_balance: string (nullable = true)
#  |-- power_shot_power: string (nullable = true)
#  |-- power_jumping: string (nullable = true)
#  |-- power_stamina: string (nullable = true)
#  |-- power_strength: string (nullable = true)
#  |-- power_long_shots: string (nullable = true)
#  |-- mentality_aggression: string (nullable = true)
#  |-- mentality_interceptions: string (nullable = true)
#  |-- mentality_positioning: string (nullable = true)
#  |-- mentality_vision: string (nullable = true)
#  |-- mentality_penalties: string (nullable = true)
#  |-- mentality_composure: string (nullable = true)
#  |-- defending_marking_awareness: string (nullable = true)
#  |-- defending_standing_tackle: string (nullable = true)
#  |-- defending_sliding_tackle: string (nullable = true)
#  |-- goalkeeping_diving: string (nullable = true)
#  |-- goalkeeping_handling: string (nullable = true)
#  |-- goalkeeping_kicking: string (nullable = true)
#  |-- goalkeeping_positioning: string (nullable = true)
#  |-- goalkeeping_reflexes: string (nullable = true)
#  |-- goalkeeping_speed: string (nullable = true)
#  |-- ls: string (nullable = true)
#  |-- st: string (nullable = true)
#  |-- rs: string (nullable = true)
#  |-- lw: string (nullable = true)
#  |-- lf: string (nullable = true)
#  |-- cf: string (nullable = true)
#  |-- rf: string (nullable = true)
#  |-- rw: string (nullable = true)
#  |-- lam: string (nullable = true)
#  |-- cam: string (nullable = true)
#  |-- ram: string (nullable = true)
#  |-- lm: string (nullable = true)
#  |-- lcm: string (nullable = true)
#  |-- cm: string (nullable = true)
#  |-- rcm: string (nullable = true)
#  |-- rm: string (nullable = true)
#  |-- lwb: string (nullable = true)
#  |-- ldm: string (nullable = true)
#  |-- cdm: string (nullable = true)
#  |-- rdm: string (nullable = true)
#  |-- rwb: string (nullable = true)
#  |-- lb: string (nullable = true)
#  |-- lcb: string (nullable = true)
#  |-- cb: string (nullable = true)
#  |-- rcb: string (nullable = true)
#  |-- rb: string (nullable = true)
#  |-- gk: string (nullable = true)
#  |-- player_face_url: string (nullable = true)
#  |-- club_logo_url: string (nullable = true)
#  |-- club_flag_url: string (nullable = true)
#  |-- nation_logo_url: string (nullable = true)
#  |-- nation_flag_url: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- Serial_no: long (nullable = true)

# %%
#typecasting
from pyspark.sql.functions import col
casted_types_df = df_final.withColumn("dob2", col("dob").cast("string")).drop("dob")
casted_types_df = casted_types_df.withColumn("club_joined2", col("club_joined").cast("string")).drop("club_joined")

#checking for NA values
from pyspark.sql.functions import *

null_counts_plays_df = casted_types_df.select([count(when(isnan(c) | col(c).isNull(), c)).alias(c) \
                        for c in casted_types_df.columns])

null_counts_plays_df.show(truncate=False, vertical=True)
# Out:
# [Stage 51:>                                                         (0 + 1) / 1]
# -RECORD 0-----------------------------
#  sofifa_id                   | 0
#  player_url                  | 0
#  short_name                  | 0
#  long_name                   | 0
#  player_positions            | 0
#  overall                     | 0
#  potential                   | 0
#  value_eur                   | 1897
#  wage_eur                    | 1622
#  age                         | 0
#  height_cm                   | 0
#  weight_kg                   | 0
#  club_team_id                | 1630
#  club_name                   | 1630
#  league_name                 | 1630
#  league_level                | 2015
#  club_position               | 1630
#  club_jersey_number          | 1630
#  club_loaned_from            | 133774
#  club_contract_valid_until   | 1630
#  nationality_id              | 0
#  nationality_name            | 0
#  nation_team_id              | 133635
#  nation_position             | 133635
#  nation_jersey_number        | 133635
#  preferred_foot              | 0
#  weak_foot                   | 0
#  skill_moves                 | 0
#  international_reputation    | 0
#  work_rate                   | 0
#  body_type                   | 0
#  real_face                   | 0
#  release_clause_eur          | 55582
#  player_tags                 | 130765
#  player_traits               | 78771
#  pace                        | 15791
#  shooting                    | 15791
#  passing                     | 15791
#  dribbling                   | 15791
#  defending                   | 15791
#  physic                      | 15791
#  attacking_crossing          | 0
#  attacking_finishing         | 0
#  attacking_heading_accuracy  | 0
#  attacking_short_passing     | 0
#  attacking_volleys           | 0
#  skill_dribbling             | 0
#  skill_curve                 | 0
#  skill_fk_accuracy           | 0
#  skill_long_passing          | 0
#  skill_ball_control          | 0
#  movement_acceleration       | 0
#  movement_sprint_speed       | 0
#  movement_agility            | 0
#  movement_reactions          | 0
#  movement_balance            | 0
#  power_shot_power            | 0
#  power_jumping               | 0
#  power_stamina               | 0
#  power_strength              | 0
#  power_long_shots            | 0
#  mentality_aggression        | 0
#  mentality_interceptions     | 0
#  mentality_positioning       | 0
#  mentality_vision            | 0
#  mentality_penalties         | 0
#  mentality_composure         | 31778
#  defending_marking_awareness | 0
#  defending_standing_tackle   | 0
#  defending_sliding_tackle    | 0
#  goalkeeping_diving          | 0
#  goalkeeping_handling        | 0
#  goalkeeping_kicking         | 0
#  goalkeeping_positioning     | 0
#  goalkeeping_reflexes        | 0
#  goalkeeping_speed           | 126288
#  ls                          | 0
#  st                          | 0
#  rs                          | 0
#  lw                          | 0
#  lf                          | 0
#  cf                          | 0
#  rf                          | 0
#  rw                          | 0
#  lam                         | 0
#  cam                         | 0
#  ram                         | 0
#  lm                          | 0
#  lcm                         | 0
#  cm                          | 0
#  rcm                         | 0
#  rm                          | 0
#  lwb                         | 0
#  ldm                         | 0
#  cdm                         | 0
#  rdm                         | 0
#  rwb                         | 0
#  lb                          | 0
#  lcb                         | 0
#  cb                          | 0
#  rcb                         | 0
#  rb                          | 0
#  gk                          | 0
#  player_face_url             | 0
#  club_logo_url               | 1630
#  club_flag_url               | 1630
#  nation_logo_url             | 133635
#  nation_flag_url             | 0
#  year                        | 0
#  Serial_no                   | 0
#  dob2                        | 0
#  club_joined2                | 9935

# %%
casted_types_df.printSchema()
# Out:
# root
#  |-- sofifa_id: string (nullable = true)
#  |-- player_url: string (nullable = true)
#  |-- short_name: string (nullable = true)
#  |-- long_name: string (nullable = true)
#  |-- player_positions: string (nullable = true)
#  |-- overall: string (nullable = true)
#  |-- potential: string (nullable = true)
#  |-- value_eur: string (nullable = true)
#  |-- wage_eur: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- height_cm: string (nullable = true)
#  |-- weight_kg: string (nullable = true)
#  |-- club_team_id: string (nullable = true)
#  |-- club_name: string (nullable = true)
#  |-- league_name: string (nullable = true)
#  |-- league_level: string (nullable = true)
#  |-- club_position: string (nullable = true)
#  |-- club_jersey_number: string (nullable = true)
#  |-- club_loaned_from: string (nullable = true)
#  |-- club_contract_valid_until: string (nullable = true)
#  |-- nationality_id: string (nullable = true)
#  |-- nationality_name: string (nullable = true)
#  |-- nation_team_id: string (nullable = true)
#  |-- nation_position: string (nullable = true)
#  |-- nation_jersey_number: string (nullable = true)
#  |-- preferred_foot: string (nullable = true)
#  |-- weak_foot: string (nullable = true)
#  |-- skill_moves: string (nullable = true)
#  |-- international_reputation: string (nullable = true)
#  |-- work_rate: string (nullable = true)
#  |-- body_type: string (nullable = true)
#  |-- real_face: string (nullable = true)
#  |-- release_clause_eur: string (nullable = true)
#  |-- player_tags: string (nullable = true)
#  |-- player_traits: string (nullable = true)
#  |-- pace: string (nullable = true)
#  |-- shooting: string (nullable = true)
#  |-- passing: string (nullable = true)
#  |-- dribbling: string (nullable = true)
#  |-- defending: string (nullable = true)
#  |-- physic: string (nullable = true)
#  |-- attacking_crossing: string (nullable = true)
#  |-- attacking_finishing: string (nullable = true)
#  |-- attacking_heading_accuracy: string (nullable = true)
#  |-- attacking_short_passing: string (nullable = true)
#  |-- attacking_volleys: string (nullable = true)
#  |-- skill_dribbling: string (nullable = true)
#  |-- skill_curve: string (nullable = true)
#  |-- skill_fk_accuracy: string (nullable = true)
#  |-- skill_long_passing: string (nullable = true)
#  |-- skill_ball_control: string (nullable = true)
#  |-- movement_acceleration: string (nullable = true)
#  |-- movement_sprint_speed: string (nullable = true)
#  |-- movement_agility: string (nullable = true)
#  |-- movement_reactions: string (nullable = true)
#  |-- movement_balance: string (nullable = true)
#  |-- power_shot_power: string (nullable = true)
#  |-- power_jumping: string (nullable = true)
#  |-- power_stamina: string (nullable = true)
#  |-- power_strength: string (nullable = true)
#  |-- power_long_shots: string (nullable = true)
#  |-- mentality_aggression: string (nullable = true)
#  |-- mentality_interceptions: string (nullable = true)
#  |-- mentality_positioning: string (nullable = true)
#  |-- mentality_vision: string (nullable = true)
#  |-- mentality_penalties: string (nullable = true)
#  |-- mentality_composure: string (nullable = true)
#  |-- defending_marking_awareness: string (nullable = true)
#  |-- defending_standing_tackle: string (nullable = true)
#  |-- defending_sliding_tackle: string (nullable = true)
#  |-- goalkeeping_diving: string (nullable = true)
#  |-- goalkeeping_handling: string (nullable = true)
#  |-- goalkeeping_kicking: string (nullable = true)
#  |-- goalkeeping_positioning: string (nullable = true)
#  |-- goalkeeping_reflexes: string (nullable = true)
#  |-- goalkeeping_speed: string (nullable = true)
#  |-- ls: string (nullable = true)
#  |-- st: string (nullable = true)
#  |-- rs: string (nullable = true)
#  |-- lw: string (nullable = true)
#  |-- lf: string (nullable = true)
#  |-- cf: string (nullable = true)
#  |-- rf: string (nullable = true)
#  |-- rw: string (nullable = true)
#  |-- lam: string (nullable = true)
#  |-- cam: string (nullable = true)
#  |-- ram: string (nullable = true)
#  |-- lm: string (nullable = true)
#  |-- lcm: string (nullable = true)
#  |-- cm: string (nullable = true)
#  |-- rcm: string (nullable = true)
#  |-- rm: string (nullable = true)
#  |-- lwb: string (nullable = true)
#  |-- ldm: string (nullable = true)
#  |-- cdm: string (nullable = true)
#  |-- rdm: string (nullable = true)
#  |-- rwb: string (nullable = true)
#  |-- lb: string (nullable = true)
#  |-- lcb: string (nullable = true)
#  |-- cb: string (nullable = true)
#  |-- rcb: string (nullable = true)
#  |-- rb: string (nullable = true)
#  |-- gk: string (nullable = true)
#  |-- player_face_url: string (nullable = true)
#  |-- club_logo_url: string (nullable = true)
#  |-- club_flag_url: string (nullable = true)
#  |-- nation_logo_url: string (nullable = true)
#  |-- nation_flag_url: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- Serial_no: long (nullable = true)
#  |-- dob2: string (nullable = true)
#  |-- club_joined2: string (nullable = true)

# %%
df_final = df_final.na.drop(subset=['club_name'])
df_final.count()
# Out:
# 140449

# %%
#Task2 Question 2
#club with highest average number of players older than 27 years accross all years
filtered_df = df_final.filter(df_final.age > 27)
grouped_df = filtered_df.groupBy("club_name","year")
sorted_df = filtered_df.orderBy("club_name")
#sorted_df = sorted_df.orderBy("year", ascending = True)
#sorted_df.show(20, vertical=True)
club_names = filtered_df.select('club_name').distinct().collect()
dictionary = {}
for name in club_names:
    df = sorted_df.filter(sorted_df.club_name == name['club_name'])
    df = df.orderBy('year', ascending = True)
    distinct_years = df.select('year').distinct().orderBy('year')
    dictionary[name['club_name']] = (df.count() / distinct_years.count())
    #distinct_values.show()
    #print(distinct_years.count())
    #print(df.count())
    
    #df.show(1, vertical = True)
    
print(dictionary)
# Out:
# {'Palermo': 7.2, 'Yeovil Town': 5.4, 'CD Everton de Viña del Mar': 8.25, 'Shonan Bellmare': 11.0, 'Göztepe SK': 10.0, 'FC Voluntari': 8.333333333333334, 'Salford City': 7.666666666666667, 'Santiago Wanderers': 6.0, 'Carpi': 3.8, '1. FC Union Berlin': 9.125, 'Crucero del Norte': 14.0, 'Sagan Tosu': 12.333333333333334, 'Guangzhou FC': 12.5, 'Jiangsu FC': 11.0, 'Karlsruher SC': 8.125, 'Puebla FC': 12.75, 'Cheltenham Town': 5.714285714285714, 'Club Independiente Santa Fe': 9.571428571428571, 'SC Paderborn 07': 6.714285714285714, 'Argentinos Juniors': 9.166666666666666, 'Shandong Taishan': 13.5, 'San Lorenzo de Almagro': 10.125, 'SC Magna Wiener Neustadt': 6.0, 'SpVgg Unterhaching': 8.0, 'Shelbourne FC': 8.0, 'GFC Ajaccio': 8.8, 'Universidad Católica': 10.875, 'FC Luzern': 6.375, 'Club Athletico Paranaense': 12.666666666666666, 'AIK': 11.0, 'SC Heerenveen': 2.25, 'Sandefjord Fotball': 6.4, 'SKA Khabarovsk': 15.0, 'Fortaleza': 8.0, 'CD Universidad de Concepción': 12.0, 'GIF Sundsvall': 6.8, 'Santos': 12.0, 'BB Erzurumspor': 16.5, 'Delfín Sporting Club': 8.0, 'AC Mineros de Guayana': 10.5, 'Carlos A. Mannucci': 9.0, 'NAC Breda': 3.0, 'Mansfield Town': 8.125, 'Hibernian': 9.4, 'América de Cali': 9.4, 'FC Tosno': 7.0, 'Rapid București': 11.0, 'Club The Strongest': 12.0, 'Toronto FC': 10.625, 'Perth Glory': 9.5, 'AC Ajaccio': 7.875, 'En Avant de Guingamp': 9.25, 'SC Preußen Münster': 4.333333333333333, 'Estudiantes de Mérida': 9.0, 'Trapani': 9.5, 'Racing Club': 12.5, 'RC Celta de Vigo': 6.625, 'Real Sporting de Gijón': 6.375, 'Birmingham City': 9.5, 'Unión de Santa Fe': 6.714285714285714, 'Extremadura UD': 15.5, 'AC Monza': 13.5, 'Club Nacional': 9.5, 'Belgrano de Córdoba': 9.4, 'Swansea City': 7.75, 'Montpellier Hérault SC': 8.625, 'Hellas Verona': 11.125, 'Urawa Red Diamonds': 14.0, 'Portimonense SC': 4.4, 'Dalkurd FF': 7.0, 'Castellammare di Stabia': 12.0, 'FC Krasnodar': 10.5, 'FC Vestsjælland': 11.0, 'Deportivo Toluca': 12.0, 'Falkenbergs FF': 7.2, 'FC St. Gallen 1879': 5.285714285714286, 'Sanfrecce Hiroshima': 13.0, 'Avaí FC': 13.666666666666666, '1. FC Magdeburg': 5.6, 'Al Taawoun': 11.0, 'Club América': 8.875, 'Club Deportes Temuco': 10.666666666666666, 'SG Dynamo Dresden': 5.833333333333333, 'Fatih Karagümrük S.K.': 12.0, 'FC Seoul': 11.75, 'Sunderland': 7.875, 'Unión Española': 7.5, 'Botafogo': 11.4, 'Vejle Boldklub': 4.333333333333333, 'Metropolitanos de Caracas FC': 9.0, 'FC Viktoria 1889 Berlin': 7.0, 'CD Cobreloa': 7.0, 'Notts County': 11.8, 'PFC CSKA Moscow': 7.25, 'Hamilton Academical FC': 5.714285714285714, 'Ternana': 5.0, 'Chesterfield': 7.0, 'Envigado FC': 4.166666666666667, 'VfL Osnabrück': 8.6, 'Górnik Zabrze': 6.285714285714286, 'Jaguares de Chiapas': 12.333333333333334, 'Uniautónoma FC': 11.0, 'Atlanta United': 8.4, 'Neuchâtel Xamax FCS': 9.0, 'Al Ain FC': 9.333333333333334, 'CS Mioveni': 10.0, 'CD Huachipato': 5.625, 'Pohang Steelers': 8.875, 'Derry City': 4.25, 'Sport Club do Recife': 14.666666666666666, 'Viktoria Köln': 8.0, 'Unión Deportiva Las Palmas': 9.875, 'FC Red Bull Salzburg': 4.375, 'Bolton Wanderers': 9.5, 'FC Chambly Oise': 13.0, 'CS Emelec': 9.5, 'Milton Keynes Dons': 5.0, 'Nîmes Olympique': 4.375, 'Korona Kielce': 6.333333333333333, 'Rio Ave FC': 5.428571428571429, 'Hebei FC': 13.0, 'Al Hazem': 9.25, 'Flamengo': 11.0, 'Zenit St. Petersburg': 10.0, 'Ross County FC': 6.714285714285714, 'Demir Grup Sivasspor': 13.857142857142858, 'La Berrichonne de Châteauroux': 7.4, 'Krylya Sovetov Samara': 7.5, 'Varbergs BoIS FC': 5.0, 'Real Valladolid CF': 9.75, 'Sporting Lokeren': 8.2, 'Moreirense FC': 6.5, 'Associação Académica de Coimbra': 6.5, 'Minnesota United FC': 13.2, 'San Martin de Tucumán': 10.0, 'Zamora Fútbol Club': 7.0, 'Junior FC': 12.0, 'Suwon FC': 12.0, 'Wexford Youths': 4.0, 'Macclesfield Town': 6.5, 'Degerfors IF': 9.0, 'Brisbane Roar': 7.625, 'Bradford City': 7.625, 'Club Atlas': 8.375, 'Boavista FC': 7.375, 'Club Necaxa': 9.666666666666666, 'Manchester United': 9.75, 'Antalyaspor': 14.0, 'Al Fa ...

# %%
sorted_dict = dict(sorted(dictionary.items(), key=lambda item: item[1], reverse=True))
print(sorted_dict)
# Out:
# {'Dorados de Sinaloa': 19.0, 'Matsumoto Yamaga FC': 19.0, 'Shanghai Shenhua FC': 18.5, 'Qingdao FC': 18.0, 'Club Deportivo Jorge Wilstermann': 17.5, 'Altay SK': 17.0, 'Guaireña FC': 17.0, 'İstanbul Başakşehir FK': 16.625, 'BB Erzurumspor': 16.5, 'Club Olimpia': 16.5, 'Sport Huancayo': 16.5, 'Beijing Renhe FC': 16.0, 'Paraná': 16.0, 'Sandecja Nowy Sącz': 16.0, 'CFR Cluj': 15.666666666666666, 'Extremadura UD': 15.5, 'Parma': 15.166666666666666, 'SKA Khabarovsk': 15.0, 'Joinville': 15.0, 'Criciúma': 15.0, 'Ventforet Kofu': 15.0, 'Padova': 15.0, 'US Cremonese': 15.0, 'Jeonbuk Hyundai Motors': 14.75, 'Júbilo Iwata': 14.75, 'Beijing Guoan FC': 14.75, 'Sport Club do Recife': 14.666666666666666, 'Gazişehir Gaziantep F.K.': 14.666666666666666, 'Fútbol Club Juárez': 14.666666666666666, 'AFC Hermannstadt': 14.5, 'Changchun Yatai FC': 14.5, 'Club Always Ready': 14.5, 'Club Atlético Nacional Potosí': 14.5, 'Associação Chapecoense de Futebol': 14.4, 'Shimizu S-Pulse': 14.2, 'Patronato': 14.166666666666666, 'Vissel Kobe': 14.166666666666666, 'Crucero del Norte': 14.0, 'Urawa Red Diamonds': 14.0, 'Antalyaspor': 14.0, 'Al Shoulla': 14.0, 'Santa Cruz': 14.0, 'Guizhou Zhicheng FC': 14.0, 'Wuhan FC': 14.0, 'Akhisar Belediyespor': 14.0, 'FC Tom Tomsk': 14.0, 'Figueirense': 14.0, 'UCAM Murcia CF': 14.0, 'Leones Negros de la UdeG': 14.0, 'Deportivo Binacional': 14.0, 'Tianjin Jinmen Tiger FC': 14.0, 'Demir Grup Sivasspor': 13.857142857142858, 'Guangzhou City': 13.75, 'Avaí FC': 13.666666666666666, 'Tiburones Rojos de Veracruz': 13.666666666666666, 'Club Atlético Central Córdoba': 13.666666666666666, 'Curicó Unido': 13.666666666666666, 'Cerezo Osaka': 13.6, 'Shandong Taishan': 13.5, 'AC Monza': 13.5, 'FC Cartagena': 13.5, 'Omiya Ardija': 13.5, 'América Futebol Clube': 13.5, 'FC Lokomotiv Moscow': 13.5, 'Yokohama FC': 13.5, 'Ponte Preta': 13.5, 'Al Fayha': 13.4, 'Arsenal Tula': 13.333333333333334, 'Crystal Palace': 13.25, 'Cruzeiro': 13.25, 'Minnesota United FC': 13.2, 'Aytemiz Alanyaspor': 13.166666666666666, 'Fenerbahçe SK': 13.125, 'Sanfrecce Hiroshima': 13.0, 'FC Chambly Oise': 13.0, 'Hebei FC': 13.0, 'Club Atlético Tigre': 13.0, 'Club Sportivo Luqueño': 13.0, 'Al Tai': 13.0, 'Chievo Verona': 13.0, '12 de Octubre FC': 13.0, 'Club Libertad': 13.0, 'Radomiak Radom': 13.0, 'Denizlispor': 13.0, 'Lobos BUAP': 13.0, 'Atakaş Hatayspor': 13.0, 'Shijiazhuang Ever Bright F.C.': 13.0, 'MKE Ankaragücü': 13.0, 'SD Amorebieta': 13.0, 'Club Atlético Palmaflor': 13.0, 'Watford': 13.0, 'Vitória': 13.0, 'Juventus': 13.0, 'Tigres U.A.N.L.': 12.875, 'Galatasaray SK': 12.875, 'Ulsan Hyundai FC': 12.875, 'Gangwon FC': 12.8, 'Puebla FC': 12.75, 'Club Athletico Paranaense': 12.666666666666666, 'KFC Uerdingen 05': 12.666666666666666, 'Burnley': 12.625, 'Guangzhou FC': 12.5, 'Racing Club': 12.5, 'Stoke City': 12.5, 'Palmeiras': 12.5, 'Lecce': 12.5, 'Vegalta Sendai': 12.5, 'Seattle Sounders FC': 12.5, 'Henan Songshan Longmen FC': 12.5, 'Al Adalah': 12.5, 'Campionii FC Arges': 12.5, 'Avispa Fukuoka': 12.5, 'Orlando Pirates': 12.5, 'Sagan Tosu': 12.333333333333334, 'Jaguares de Chiapas': 12.333333333333334, 'Goiás': 12.333333333333334, 'Grêmio': 12.333333333333334, 'Kawasaki Frontale': 12.333333333333334, 'FC Tokyo': 12.333333333333334, 'Osmanlıspor': 12.333333333333334, 'São Paulo': 12.25, 'Lazio': 12.125, 'CD Universidad de Concepción': 12.0, 'Santos': 12.0, 'Club The Strongest': 12.0, 'Castellammare di Stabia': 12.0, 'Deportivo Toluca': 12.0, 'Fatih Karagümrük S.K.': 12.0, 'Junior FC': 12.0, 'Suwon FC': 12.0, 'Miedź Legnica': 12.0, 'Shenzhen FC': 12.0, 'Club Deportivo El Nacional': 12.0, 'SC East Bengal FC': 12.0, 'Kardemir Karabükspor': 12.0, 'PGE FKS Stal Mielec': 12.0, 'Cruz Azul': 12.0, 'C.D. Castellón': 12.0, 'Torpedo Moscow': 12.0, 'APOEL Nicosia FC': 12.0, 'Damac FC': 12.0, 'Chivas USA': 12.0, 'Club River Plate Asunción': 12.0, 'Adana Demirspor': 12.0, 'FC Viktoria Plzeň': 12.0, 'Chongqing Liangjiang Athletic': 12.0, 'Nagoya Grampus': 12.0, 'Coritiba': 12.0, 'FC Mor ...

# %%
from pyspark.sql.types import StructType, StructField, FloatType, StringType, DoubleType
def top_Y_clubs(Y):
    sorted_list_values = list(sorted_dict.values())
    print_sorted = sorted_list_values[:Y]
    Z = Y - 1
    while (sorted_list_values[Z + 1] == sorted_list_values[Y]):
        print_sorted.append(sorted_list_values[Z + 1])
        Z = Z + 1
    length = len(print_sorted)
    list_of_dicts = []
    for key, value in sorted_dict.items():
        #print(key)
        #print(value)
        list_of_dicts.append({key: value})
    #rdd = spark.sparkContext.parallelize(list_of_dicts)
    schema = StructType([
        StructField("Club_name", StringType(), True),
        StructField("Average", DoubleType(), True)
    ])

    rdd = spark.sparkContext.parallelize(list_of_dicts)
    df = spark.createDataFrame(rdd.map(lambda x: (list(x.keys())[0], list(x.values())[0])), schema)
    df = df.limit(length)

    df.show(length, vertical = True)
    
Y_val = int(input("Enter the required number of clubs: "))
top_Y_clubs(Y_val)
# Out:
# Enter the required number of clubs: 5
# [Stage 9159:>                                                       (0 + 4) / 4]
# -RECORD 0-------------------------
#  Club_name | 1. FC Saarbrücken
#  Average   | 10.5
# -RECORD 1-------------------------
#  Club_name | Najran SC
#  Average   | 10.5
# -RECORD 2-------------------------
#  Club_name | US Créteil-Lusitanos
#  Average   | 10.5
# -RECORD 3-------------------------
#  Club_name | Amkar Perm
#  Average   | 10.5
# -RECORD 4-------------------------
#  Club_name | UE Llagostera
#  Average   | 10.5
# -RECORD 5-------------------------
#  Club_name | Coquimbo Unido
#  Average   | 10.5
# -RECORD 6-------------------------
#  Club_name | Mazatlán Futbol Club
#  Average   | 10.5

# %%
#task2 - 3 question
from pyspark.sql.types import StructType, StructField, FloatType, StringType, DoubleType, IntegerType
df_nation_position = df_final.groupBy("year", "nation_position").agg(count("*").alias("count"))
#df_nation_position.show(vertical=True)
sorted_df2 = df_nation_position.orderBy("year")
years = [15, 16, 17, 18, 19, 20, 21, 22]
dict_nation_position = {}
for year in years:
    
    sorted_df2_i = sorted_df2.filter(sorted_df2.year == year)
    #sorted_df2_i.show(vertical=True)
    sorted_df2_final = sorted_df2_i.orderBy(desc("count"))
    s = sorted_df2_final.na.drop()
    s = s.where(s.nation_position != 'SUB')
    #s.show(vertical=True)
    first_value = s.collect()[0]['nation_position']
    dict_nation_position[year] = first_value
    
#df_nation_position.show(10, vertical= True)
#print(dict_nation_position)
list_of_dicts2 = []
for key, value in dict_nation_position.items():
    list_of_dicts2.append({key: value})
#print(list_of_dicts2)
schema = StructType([
        StructField("Year", IntegerType(), True),
        StructField("Pos", StringType(), True), 
    
    ])

rdd = spark.sparkContext.parallelize(list_of_dicts2)
df = spark.createDataFrame(rdd.map(lambda x: (list(x.keys())[0], list(x.values())[0])), schema)

df.show()
# Out:
# +----+---+
# |Year|Pos|
# +----+---+
# |  15| GK|
# |  16|RCB|
# |  17| GK|
# |  18|RCB|
# |  19| GK|
# |  20|LCB|
# |  21|LCB|
# |  22|LCB|
# +----+---+
